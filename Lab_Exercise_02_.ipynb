# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnEldho/Data-Science-Lab/blob/main/Lab_Exercise_02_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import pandas package • Learn the usage and syntax of the following functions. Try it in lab using your own data

# %% [markdown]
# # **Pandas**

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-775513e2-af3f-4fa7-be20-c0965f31edfe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-775513e2-af3f-4fa7-be20-c0965f31edfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.shape)
# Out:
# (8, 6)

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  8 non-null      int64
#  1   Name        8 non-null      object
#  2   Age         8 non-null      int64
#  3   Marks       8 non-null      int64
#  4   Attendance  8 non-null      int64
#  5   Balance     8 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 516.0+ bytes

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.shape)
# Out:
# (8, 6)

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.describe())
# Out:
#        Student_ID        Age      Marks  Attendance      Balance
# count     8.00000   8.000000   8.000000    8.000000     8.000000
# mean    104.50000  21.500000  87.000000   91.375000   450.000000
# std       2.44949   1.195229   5.345225    4.206712   634.710283
# min     101.00000  20.000000  78.000000   85.000000  -500.000000
# 25%     102.75000  20.750000  84.250000   88.750000  -125.000000
# 50%     104.50000  21.500000  87.500000   91.000000   650.000000
# 75%     106.25000  22.250000  90.250000   94.250000   925.000000
# max     108.00000  23.000000  95.000000   98.000000  1200.000000

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.head())
# Out:
#    Student_ID  Name  Age  Marks  Attendance  Balance
# 0         101   Ann   21     85          92     1000
# 1         102  John   22     90          88     -500
# 2         103  Sara   20     78          95      800
# 3         104   Tom   23     88          90     -200
# 4         105   Eva   21     95          98     1200

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.tail())
# Out:
#    Student_ID   Name  Age  Marks  Attendance  Balance
# 3         104    Tom   23     88          90     -200
# 4         105    Eva   21     95          98     1200
# 5         106  David   22     82          85      500
# 6         107  Meera   20     91          94     -100
# 7         108   Alex   23     87          89      900

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df.count())
# Out:
# Student_ID    8
# Name          8
# Age           8
# Marks         8
# Attendance    8
# Balance       8
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].sum())
# Out:
# Age      172
# Marks    696
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].sum())
# Out:
# Age      172
# Marks    696
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].mean())
# Out:
# Age      21.5
# Marks    87.0
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].median())
# Out:
# Age      21.5
# Marks    87.5
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].mode())
# Out:
#     Age  Marks
# 0  20.0     78
# 1  21.0     82
# 2  22.0     85
# 3  23.0     87
# 4   NaN     88
# 5   NaN     90
# 6   NaN     91
# 7   NaN     95

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].std())
# Out:
# Age      1.195229
# Marks    5.345225
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].min())
# Out:
# Age      20
# Marks    78
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age","Marks"]].max())
# Out:
# Age      23
# Marks    95
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df["Balance"].abs())
# Out:
# 0    1000
# 1     500
# 2     800
# 3     200
# 4    1200
# 5     500
# 6     100
# 7     900
# Name: Balance, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df[["Age"]].prod())
# Out:
# Age    45164750400
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df["Marks"].cumsum())
# Out:
# 0     85
# 1    175
# 2    253
# 3    341
# 4    436
# 5    518
# 6    609
# 7    696
# Name: Marks, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df["Age"].cumprod())
# Out:
# 0             21
# 1            462
# 2           9240
# 3         212520
# 4        4462920
# 5       98184240
# 6     1963684800
# 7    45164750400
# Name: Age, dtype: int64
